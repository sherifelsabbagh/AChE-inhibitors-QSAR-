# %%
import pandas as pd 
import chemplot
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset_std.csv",sep="\t")

# %%
df.head()
# Out:
#   Molecule ChEMBL ID                                             smiles  \
# 0           CHEMBL94        CNC(=O)Oc1ccc2c(c1)[C@]1(C)CCN(C)[C@@H]1N2C
# 1        CHEMBL11805  COc1ccccc1CN(C)CCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)...
# 2           CHEMBL95                            Nc1c2c(nc3ccccc13)CCCC2
# 3       CHEMBL132377  COc1ccccc1CNCCCCCC(=O)N(C)CCCCCCCCN(C)C(=O)CCC...
# 4       CHEMBL134488  COc1ccccc1CNCCCCCC(=O)NCCCCCCCCNC(=O)CCCCCNCc1...
#
#    label  pIC50
# 0      0  -7.85
# 1      0  -6.77
# 2      0  -6.66
# 3      0  -6.51
# 4      0  -5.73

# %%
from chemplot import Plotter

# %%
cp = Plotter.from_smiles(df["smiles"],target=df["label"],target_type="C")
# Out:
# sim_type indicates the similarity type by which the plots are constructed.
# The supported similarity types are structural and tailored.
# Because a target list has been provided 'tailored' as been selected as sym_type.
# /Users/sherifelsabbagh/opt/anaconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
cp.pca()
# Out:
#       PC-1 (8%)  PC-2 (7%)  target
# 0      0.298727   4.455456       0
# 1      2.969026   0.921202       0
# 2     -2.582368   1.447162       0
# 3      3.012630   0.584223       0
# 4      3.052839   0.241710       0
# ...         ...        ...     ...
# 4999   1.456037  -3.333500       1
# 5000   1.386882  -3.000828       1
# 5001   1.148090  -3.069146       1
# 5002   2.008636  -3.520565       1
# 5003   2.241267  -3.104125       1
#
# [5004 rows x 3 columns]

# %%
cp.visualize_plot()
# Out:
# <AxesSubplot:label='scatter', title={'center':'PCA plot'}, xlabel='PC-1 (8%)', ylabel='PC-2 (7%)'>

# %%
cp.tsne()
cp.visualize_plot()
# Out:
# /Users/sherifelsabbagh/opt/anaconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/sherifelsabbagh/opt/anaconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# <AxesSubplot:label='scatter', title={'center':'t-SNE plot'}, xlabel='t-SNE-1', ylabel='t-SNE-2'>

# %%
cp.umap()
cp.visualize_plot()
# Out:
# /Users/sherifelsabbagh/opt/anaconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# <AxesSubplot:label='scatter', title={'center':'UMAP plot'}, xlabel='UMAP-1', ylabel='UMAP-2'>

# %%
cp = Plotter.from_smiles(df["smiles"],target=df["label"],target_type="C",sim_type="structural")

# %%
cp.pca()
cp.visualize_plot()
# Out:
# <AxesSubplot:label='scatter', title={'center':'PCA plot'}, xlabel='PC-1 (8%)', ylabel='PC-2 (5%)'>

# %%
cp = Plotter.from_smiles(df["smiles"],target=df["label"],target_type="C",sim_type="tailored")
cp.pca()
cp.interactive_plot(show_plot=True)
# Out:
# /Users/sherifelsabbagh/opt/anaconda3/envs/my-rdkit-env/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Figure(id='1002', ...)

# %%
cp.cluster()
# Out:
#       PC-1 (8%)  PC-2 (7%)  target  clusters
# 0      0.299107   4.453472       0         2
# 1      2.969750   0.921127       0         2
# 2     -2.582413   1.447245       0         0
# 3      3.013301   0.583980       0         2
# 4      3.053457   0.241301       0         1
# ...         ...        ...     ...       ...
# 4999   1.456247  -3.335171       1         1
# 5000   1.387094  -3.002549       1         1
# 5001   1.148299  -3.070865       1         1
# 5002   2.008850  -3.522200       1         1
# 5003   2.241535  -3.105829       1         1
#
# [5004 rows x 4 columns]

# %%
cp.interactive_plot(clusters=True,show_plot=True)
# Out:
# Tabs(id='1390', ...)
